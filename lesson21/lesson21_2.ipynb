# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  1.209256  0.881667
# 1    a  two -1.038460 -0.900517
# 2    b  one -1.382556 -0.410611
# 3    b  two -1.588654 -0.649001
# 4    a  one -0.567119  2.574588

# %%
df1 = df.set_index(keys=['key1','key2'])
df1
# Out:
#               data1     data2
# key1 key2
# a    one   1.209256  0.881667
#      two  -1.038460 -0.900517
# b    one  -1.382556 -0.410611
#      two  -1.588654 -0.649001
# a    one  -0.567119  2.574588

# %%
df1.columns.name = 'data'
df1
# Out:
# data          data1     data2
# key1 key2
# a    one   1.209256  0.881667
#      two  -1.038460 -0.900517
# b    one  -1.382556 -0.410611
#      two  -1.588654 -0.649001
# a    one  -0.567119  2.574588

# %%
df2 = df1.groupby(level=['key1','key2']).mean()
df2
# Out:
# data          data1     data2
# key1 key2
# a    one   0.321069  1.728127
#      two  -1.038460 -0.900517
# b    one  -1.382556 -0.410611
#      two  -1.588654 -0.649001

# %%
df2.unstack(level='key1')
# Out:
# data     data1               data2
# key1         a         b         a         b
# key2
# one   0.321069 -1.382556  1.728127 -0.410611
# two  -1.038460 -1.588654 -0.900517 -0.649001
